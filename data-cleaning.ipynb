# %%
from azure.storage.blob import BlobServiceClient
import pandas as pd
import time

STORAGEACCOUNTURL= 'https://adlstrnpython.blob.core.windows.net'
STORAGEACCOUNTKEY= 'P7yZF8jDYk66EfWz0jEsEYfC0QBQrNzuG4T4ynKLb23DoFaFDmdIx33J9pWYm/McJ0RUjHAic5Ug+AStCk/mVQ=='
LOCALFILENAME= 'bronze'
CONTAINERNAME= 'bronze'
BLOBNAME= 'titanic_train.csv'

#download from blob
t1 = time.time()
blob_service_client_instance = BlobServiceClient(account_url=STORAGEACCOUNTURL, credential=STORAGEACCOUNTKEY)
blob_client_instance = blob_service_client_instance.get_blob_client(CONTAINERNAME, BLOBNAME, snapshot=None)
with open(LOCALFILENAME, "wb") as my_blob:
    blob_data = blob_client_instance.download_blob()
    blob_data.readinto(my_blob)
t2=time.time()
print(("It takes %s seconds to download "+BLOBNAME) % (t2 - t1))
# Out:
# It takes 1.1628949642181396 seconds to download titanic_train.csv

# %%
dataframe_blobdata = pd.read_csv(LOCALFILENAME)
dataframe_blobdata
# Out:
#      passenger_id  pclass                                               name  \
# 0            1216       3                                 Smyth, Miss. Julia
# 1             699       3                                    Cacic, Mr. Luka
# 2            1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3             449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4             576       2                                    Veal, Mr. James
# ..            ...     ...                                                ...
# 845           158       1                        Hipkins, Mr. William Edward
# 846           174       1                            Kent, Mr. Edward Austin
# 847           467       2                Kantor, Mrs. Sinai (Miriam Sternin)
# 848          1112       3                          Peacock, Miss. Treasteall
# 849           425       2                              Greenberg, Mr. Samuel
#
# ...

# %%
dataframe_blobdata.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4   NaN
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN   NaN
#
#                   home.dest  survived
# ...

# %%
dataframe_blobdata.tail()
# Out:
#      passenger_id  pclass                                 name     sex   age  \
# 845           158       1          Hipkins, Mr. William Edward    male  55.0
# 846           174       1              Kent, Mr. Edward Austin    male  58.0
# 847           467       2  Kantor, Mrs. Sinai (Miriam Sternin)  female  24.0
# 848          1112       3            Peacock, Miss. Treasteall  female   3.0
# 849           425       2                Greenberg, Mr. Samuel    male  52.0
#
#      sibsp  parch              ticket    fare cabin embarked boat   body  \
# 845      0      0                 680  50.000   C39        S  NaN    NaN
# 846      0      0               11771  29.700   B37        C  NaN  258.0
# 847      1      0              244367  26.000   NaN        S   12    NaN
# 848      1      1  SOTON/O.Q. 3101315  13.775   NaN        S  NaN    NaN
# 849      0      0              250647  13.000   NaN        S  NaN   19.0
#
#                home.dest  survived
# ...

# %%
dataframe_blobdata.sample(5)
# Out:
#      passenger_id  pclass                              name   sex   age  \
# 782           154       1        Hays, Mr. Charles Melville  male  55.0
# 636           336       2                 Beane, Mr. Edward  male  32.0
# 607           378       2               Collyer, Mr. Harvey  male  31.0
# 47           1179       3             Sage, Mr. John George  male   NaN
# 530           834       3  Gronnestad, Mr. Daniel Danielsen  male  32.0
#
#      sibsp  parch      ticket     fare cabin embarked boat   body  \
# 782      1      1       12749  93.5000   B69        S  NaN  307.0
# 636      1      0        2908  26.0000   NaN        S   13    NaN
# 607      1      1  C.A. 31921  26.2500   NaN        S  NaN    NaN
# 47       1      9    CA. 2343  69.5500   NaN        S  NaN    NaN
# 530      0      0        8471   8.3625   NaN        S  NaN    NaN
#
#                                    home.dest  survived
# 782                             Montreal, PQ         0
# ...

# %%
dataframe_blobdata.shape
# Out:
# (850, 15)

# %%
dataframe_blobdata.describe()
# Out:
#        passenger_id     pclass         age       sibsp       parch  \
# count    850.000000  850.00000  676.000000  850.000000  850.000000
# mean     662.816471    2.32000   29.519847    0.522353    0.382353
# std      380.751936    0.83853   14.562243    1.112132    0.879511
# min        1.000000    1.00000    0.166700    0.000000    0.000000
# 25%      332.250000    2.00000   20.000000    0.000000    0.000000
# 50%      676.500000    3.00000   28.000000    0.000000    0.000000
# 75%      992.250000    3.00000   37.000000    1.000000    0.000000
# max     1307.000000    3.00000   80.000000    8.000000    9.000000
#
#              fare        body    survived
# count  849.000000   73.000000  850.000000
# mean    34.012701  165.821918    0.368235
# std     53.705779   99.068487    0.482610
# min      0.000000    4.000000    0.000000
# 25%      7.895800   75.000000    0.000000
# 50%     14.108300  166.000000    0.000000
# 75%     31.000000  260.000000    1.000000
# ...

# %%
dataframe_blobdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   passenger_id  850 non-null    int64
#  1   pclass        850 non-null    int64
#  2   name          850 non-null    object
#  3   sex           850 non-null    object
#  4   age           676 non-null    float64
#  5   sibsp         850 non-null    int64
#  6   parch         850 non-null    int64
#  7   ticket        850 non-null    object
#  8   fare          849 non-null    float64
#  9   cabin         191 non-null    object
#  10  embarked      849 non-null    object
#  11  boat          308 non-null    object
#  12  body          73 non-null     float64
#  13  home.dest     464 non-null    object
#  14  survived      850 non-null    int64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 99.7+ KB

# %%
dict_nome_colunas = {'passenger_id': 'id', 'placss':'classe', 'name':'nome', 'sex':'sexo', 'age':'idade',
                     'sibsp':'num_irmaos_companheiro', 'parch':'num_pais_filhos', 'ticket':'num_ticket', 
                     'fare':'tarifa', 'cabin': 'cabine', 'embarked':'porto_embarque', 'boat':'barco', 
                     'body':'corpo', 'home.dest': 'destino', 'survived':'sobreviveu'}

# %%
dataframe_blobdata.rename(columns=dict_nome_colunas, inplace=True)

# %%
dataframe_blobdata
# Out:
#        id  pclass                                               nome    sexo  \
# 0    1216       3                                 Smyth, Miss. Julia  female
# 1     699       3                                    Cacic, Mr. Luka    male
# 2    1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...  female
# 3     449       2              Hocking, Mrs. Elizabeth (Eliza Needs)  female
# 4     576       2                                    Veal, Mr. James    male
# ..    ...     ...                                                ...     ...
# 845   158       1                        Hipkins, Mr. William Edward    male
# 846   174       1                            Kent, Mr. Edward Austin    male
# 847   467       2                Kantor, Mrs. Sinai (Miriam Sternin)  female
# 848  1112       3                          Peacock, Miss. Treasteall  female
# 849   425       2                              Greenberg, Mr. Samuel    male
#
# ...

# %%
dataframe_blobdata.columns.values
# Out:
# array(['id', 'pclass', 'nome', 'sexo', 'idade', 'num_irmaos_companheiro',
#        'num_pais_filhos', 'num_ticket', 'tarifa', 'cabine',
#        'porto_embarque', 'barco', 'corpo', 'destino', 'sobreviveu'],
#       dtype=object)

# %%
dataframe_blobdata['sexo'] = dataframe_blobdata['sexo'].replace('female', 'F')

# %%
dataframe_blobdata['sexo'] = dataframe_blobdata['sexo'].replace('male', 'M')

# %%
dataframe_blobdata
# Out:
#        id  pclass                                               nome sexo  \
# 0    1216       3                                 Smyth, Miss. Julia    F
# 1     699       3                                    Cacic, Mr. Luka    M
# 2    1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...    F
# 3     449       2              Hocking, Mrs. Elizabeth (Eliza Needs)    F
# 4     576       2                                    Veal, Mr. James    M
# ..    ...     ...                                                ...  ...
# 845   158       1                        Hipkins, Mr. William Edward    M
# 846   174       1                            Kent, Mr. Edward Austin    M
# 847   467       2                Kantor, Mrs. Sinai (Miriam Sternin)    F
# 848  1112       3                          Peacock, Miss. Treasteall    F
# 849   425       2                              Greenberg, Mr. Samuel    M
#
#      idade  num_irmaos_companheiro  num_pais_filhos          num_ticket  \
# ...

# %%
dataframe_blobdata.cabine.apply(str)
dataframe_blobdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      850 non-null    int64
#  1   pclass                  850 non-null    int64
#  2   nome                    850 non-null    object
#  3   sexo                    850 non-null    object
#  4   idade                   676 non-null    float64
#  5   num_irmaos_companheiro  850 non-null    int64
#  6   num_pais_filhos         850 non-null    int64
#  7   num_ticket              850 non-null    object
#  8   tarifa                  849 non-null    float64
#  9   cabine                  191 non-null    object
#  10  porto_embarque          849 non-null    object
#  11  barco                   308 non-null    object
#  12  corpo                   73 non-null     float64
#  13  destino                 464 non-null    object
# ...

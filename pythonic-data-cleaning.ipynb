# %%
from azure.storage.blob import BlobServiceClient
import pandas as pd
import time
import numpy as np

STORAGEACCOUNTURL= 'https://adlstrnpython.blob.core.windows.net'
STORAGEACCOUNTKEY= 'P7yZF8jDYk66EfWz0jEsEYfC0QBQrNzuG4T4ynKLb23DoFaFDmdIx33J9pWYm/McJ0RUjHAic5Ug+AStCk/mVQ=='
LOCALFILENAME= 'bronze'
CONTAINERNAME= 'bronze'
BLOBNAME= 'BL-Flickr-Images-Book.csv'

#download from blob
t1 = time.time()
blob_service_client_instance = BlobServiceClient(account_url=STORAGEACCOUNTURL, credential=STORAGEACCOUNTKEY)
blob_client_instance = blob_service_client_instance.get_blob_client(CONTAINERNAME, BLOBNAME, snapshot=None)
with open(LOCALFILENAME, "wb") as my_blob:
    blob_data = blob_client_instance.download_blob()
    blob_data.readinto(my_blob)
t2=time.time()
print(("It takes %s seconds to download "+BLOBNAME) % (t2 - t1))
# Out:
# It takes 1.7407081127166748 seconds to download BL-Flickr-Images-Book.csv

# %%
dataframe_images_book = pd.read_csv(LOCALFILENAME)
dataframe_images_book
# Out:
#       Identifier             Edition Statement      Place of Publication  \
# 0            206                           NaN                    London
# 1            216                           NaN  London; Virtue & Yorston
# 2            218                           NaN                    London
# 3            472                           NaN                    London
# 4            480  A new edition, revised, etc.                    London
# ...          ...                           ...                       ...
# 8282     4158088                           NaN                    London
# 8283     4158128                           NaN                     Derby
# 8284     4159563                           NaN                    London
# 8285     4159587                           NaN       Newcastle upon Tyne
# 8286     4160339                           NaN                    London
#
#      Date of Publication                Publisher  \
# ...

# %%
dataframe_images_book.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8287 entries, 0 to 8286
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Identifier              8287 non-null   int64
#  1   Edition Statement       773 non-null    object
#  2   Place of Publication    8287 non-null   object
#  3   Date of Publication     8106 non-null   object
#  4   Publisher               4092 non-null   object
#  5   Title                   8287 non-null   object
#  6   Author                  6509 non-null   object
#  7   Contributors            8287 non-null   object
#  8   Corporate Author        0 non-null      float64
#  9   Corporate Contributors  0 non-null      float64
#  10  Former owner            1 non-null      object
#  11  Engraver                0 non-null      float64
#  12  Issuance type           8287 non-null   object
#  13  Flickr URL              8287 non-null   object
# ...

# %%
to_drop = ['Edition Statement',
           'Corporate Author',
           'Corporate Contributors',
           'Former owner',
           'Engraver',
           'Contributors',
           'Shelfmarks']

dataframe_images_book.drop(to_drop, inplace = True, axis = 1)
dataframe_images_book.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author Issuance type                                         Flickr URL
# ...

# %%
dicio_nome_colunas = {'Identifier': 'id', 'Place of Publication': 'lugar_publicacao', 'Date of Publication': 'data_publicacao', 'Publisher': 'editor', 'Title': 'titulo',
       'Author': 'autor', 'Issuance type': 'tipo_emissao', 'Flickr URL': 'URL_flickr'}

# %%
dataframe_images_book.rename(columns=dicio_nome_colunas, inplace=True)

# %%
dataframe_images_book['id'].is_unique
# Out:
# True

# %%
dataframe_images_book.set_index('id', inplace = True)
dataframe_images_book.head()
# Out:
#              lugar_publicacao data_publicacao                 editor  \
# id
# 206                    London     1879 [1878]       S. Tinsley & Co.
# 216  London; Virtue & Yorston            1868           Virtue & Co.
# 218                    London            1869  Bradbury, Evans & Co.
# 472                    London            1851          James Darling
# 480                    London            1857   Wertheim & Macintosh
#
#                                                 titulo      autor  \
# id
# 206                  Walter Forbes. [A novel.] By A. A      A. A.
# 216  All for Greed. [A novel. The dedication signed...  A., A. A.
# 218  Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472  Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# 480  [The World in which I live, and my place in it...  A., E. S.
#
#     tipo_emissao                                         URL_flickr
# id
# 206  monographic  http://www.flickr.com/photos/britishlibrary/ta...
# ...

# %%
dataframe_images_book.columns
# Out:
# Index(['lugar_publicacao', 'data_publicacao', 'editor', 'titulo', 'autor',
#        'tipo_emissao', 'URL_flickr'],
#       dtype='object')

# %%
dataframe_images_book['data_publicacao'].head(25)
# Out:
# id
# 206            1879 [1878]
# 216                   1868
# 218                   1869
# 472                   1851
# 480                   1857
# 481                   1875
# 519                   1872
# 667                    NaN
# 874                   1676
# 1143                  1679
# 1280                  1802
# 1808                  1859
# 1905                  1888
# 1929           1839, 38-54
# 2836                  1897
# 2854                  1865
# 2956               1860-63
# 2957                  1873
# 3017                  1866
# 3131                  1899
# 4598                  1814
# 4884                  1820
# 4976                  1800
# 5382    1847, 48 [1846-48]
# 5385               [1897?]
# Name: data_publicacao, dtype: object

# %%
caracteres_indesejados = ['[', ',', '-', ']', '.', '?', '/']

def limpa_datas(item):
    data_publicacao = str(item.loc['data_publicacao'])
    
    if data_publicacao == 'nan' or data_publicacao[0] == '[':
        return np.NaN
    
    for caractere in caracteres_indesejados:
        if caractere in data_publicacao:
            indice_caractere = data_publicacao.find(caractere)
            data_publicacao = data_publicacao[:indice_caractere]
    
    return data_publicacao

dataframe_images_book['data_publicacao'] = dataframe_images_book.apply(limpa_datas, axis = 1)

# %%
dataframe_images_book.head()
# Out:
#              lugar_publicacao data_publicacao                 editor  \
# id
# 206                    London           1879        S. Tinsley & Co.
# 216  London; Virtue & Yorston            1868           Virtue & Co.
# 218                    London            1869  Bradbury, Evans & Co.
# 472                    London            1851          James Darling
# 480                    London            1857   Wertheim & Macintosh
#
#                                                 titulo      autor  \
# id
# 206                  Walter Forbes. [A novel.] By A. A      A. A.
# 216  All for Greed. [A novel. The dedication signed...  A., A. A.
# 218  Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472  Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# 480  [The World in which I live, and my place in it...  A., E. S.
#
#     tipo_emissao                                         URL_flickr
# id
# 206  monographic  http://www.flickr.com/photos/britishlibrary/ta...
# ...

# %%
dataframe_images_book.dtypes.value_counts()
# Out:
# object    7
# dtype: int64

# %%
extr = dataframe_images_book['data_publicacao'].str.extract(r'^(\d{4})', expand = False)
extr.head()
# Out:
# id
# 206    1879
# 216    1868
# 218    1869
# 472    1851
# 480    1857
# Name: data_publicacao, dtype: object

# %%
dataframe_images_book['data_publicacao'] = pd.to_numeric(extr)
dataframe_images_book['data_publicacao'].dtype
# Out:
# dtype('float64')

# %%
dataframe_images_book['data_publicacao'] = dataframe_images_book['data_publicacao'].fillna(0)

# %%
dicio_conversao = {'data_publicacao': int}

dataframe_images_book = dataframe_images_book.astype(dicio_conversao)
print(dataframe_images_book.dtypes)
# Out:
# lugar_publicacao    object
# data_publicacao      int32
# editor              object
# titulo              object
# autor               object
# tipo_emissao        object
# URL_flickr          object
# dtype: object

# %%
dataframe_images_book.isnull().sum() / len(dataframe_images_book)
# Out:
# lugar_publicacao    0.000000
# data_publicacao     0.000000
# editor              0.506215
# titulo              0.000000
# autor               0.214553
# tipo_emissao        0.000000
# URL_flickr          0.000000
# dtype: float64

# %%
dataframe_images_book.head(10)
# Out:
#                          lugar_publicacao  data_publicacao  \
# id
# 206                                London             1879
# 216              London; Virtue & Yorston             1868
# 218                                London             1869
# 472                                London             1851
# 480                                London             1857
# 481                                London             1875
# 519                                London             1872
# 667   pp. 40. G. Bryan & Co: Oxford, 1898                0
# 874                               London]             1676
# 1143                               London             1679
#
#                      editor  \
# id
# 206        S. Tinsley & Co.
# 216            Virtue & Co.
# 218   Bradbury, Evans & Co.
# 472           James Darling
# 480    Wertheim & Macintosh
# 481       William Macintosh
# 519              The Author
# 667                     NaN
# 874                     NaN
# ...

# %%
dataframe_images_book['lugar_publicacao'].head(10)
# Out:
# id
# 206                                  London
# 216                London; Virtue & Yorston
# 218                                  London
# 472                                  London
# 480                                  London
# 481                                  London
# 519                                  London
# 667     pp. 40. G. Bryan & Co: Oxford, 1898
# 874                                 London]
# 1143                                 London
# Name: lugar_publicacao, dtype: object

# %%
dataframe_images_book.loc[4157862]
# Out:
# lugar_publicacao                                  Newcastle-upon-Tyne
# data_publicacao                                                  1867
# editor                                                     T. Fordyce
# titulo              Local Records; or, Historical Register of rema...
# autor                   FORDYCE, T. - Printer, of Newcastle-upon-Tyne
# tipo_emissao                                              monographic
# URL_flickr          http://www.flickr.com/photos/britishlibrary/ta...
# Name: 4157862, dtype: object

# %%
dataframe_images_book['tipo_emissao'].value_counts()
# Out:
# monographic    8268
# continuing       19
# Name: tipo_emissao, dtype: int64

# %%
BLOBNAME= 'olympics.csv'

#download from blob
t1 = time.time()
blob_service_client_instance = BlobServiceClient(account_url=STORAGEACCOUNTURL, credential=STORAGEACCOUNTKEY)
blob_client_instance = blob_service_client_instance.get_blob_client(CONTAINERNAME, BLOBNAME, snapshot=None)
with open(LOCALFILENAME, "wb") as my_blob:
    blob_data = blob_client_instance.download_blob()
    blob_data.readinto(my_blob)
t2=time.time()
print(("It takes %s seconds to download "+BLOBNAME) % (t2 - t1))
# Out:
# It takes 0.6117668151855469 seconds to download olympics.csv

# %%
dataframe_olympics = pd.read_csv(LOCALFILENAME, header=1)
dataframe_olympics
# Out:
#                                        Unnamed: 0  ? Summer  01 !  02 !  03 !  \
# 0                               Afghanistan (AFG)        13     0     0     2
# 1                                   Algeria (ALG)        12     5     2     8
# 2                                 Argentina (ARG)        23    18    24    28
# 3                                   Armenia (ARM)         5     1     2     9
# 4                         Australasia (ANZ) [ANZ]         2     3     4     5
# ..                                            ...       ...   ...   ...   ...
# 142  Independent Olympic Participants (IOP) [IOP]         1     0     1     2
# 143                            Zambia (ZAM) [ZAM]        12     0     1     1
# 144                          Zimbabwe (ZIM) [ZIM]        12     3     4     1
# 145                        Mixed team (ZZX) [ZZX]         3     8     5     4
# 146                                        Totals        27  4809  4775  5130
#
# ...

# %%
dataframe_olympics.columns
# Out:
# Index(['Unnamed: 0', '? Summer', '01 !', '02 !', '03 !', 'Total', '? Winter',
#        '01 !.1', '02 !.1', '03 !.1', 'Total.1', '? Games', '01 !.2', '02 !.2',
#        '03 !.2', 'Combined total'],
#       dtype='object')

# %%
dicio_conversao =  {'Unnamed: 0': 'pais',
               '? Summer': 'olimpiadas_verao',
               '01 !': 'ouro',
               '02 !': 'prata',
               '03 !': 'bronze',
               '? Winter': 'olimpiadas_inverno',
               '01 !.1': 'ouro_1',
               '02 !.1': 'prata_1',
               '03 !.1': 'prata_1',
               '? Games': 'jogos',
               '01 !.2': 'ouro_2',
               '02 !.2': 'prata_2',
               '03 !.2': 'bronze_2'}

# %%
dataframe_olympics.rename(columns=dicio_conversao, inplace=True)

# %%
dataframe_olympics
# Out:
#                                              pais  olimpiadas_verao  ouro  \
# 0                               Afghanistan (AFG)                13     0
# 1                                   Algeria (ALG)                12     5
# 2                                 Argentina (ARG)                23    18
# 3                                   Armenia (ARM)                 5     1
# 4                         Australasia (ANZ) [ANZ]                 2     3
# ..                                            ...               ...   ...
# 142  Independent Olympic Participants (IOP) [IOP]                 1     0
# 143                            Zambia (ZAM) [ZAM]                12     0
# 144                          Zimbabwe (ZIM) [ZIM]                12     3
# 145                        Mixed team (ZZX) [ZZX]                 3     8
# 146                                        Totals                27  4809
#
#      prata  bronze  Total  olimpiadas_inverno  ouro_1  prata_1  prata_1  \
# ...

# %%
def testes():
    return dataframe_olympics['ouro'].argmax()

# %%
testes()
# Out:
# 146
